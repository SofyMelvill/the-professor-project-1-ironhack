# %%
import pandas as pd

# %%
skills_df = pd.read_csv("kaggle_related_skills.csv")
skills_df.head()
# Out:
#                         name           related_1                   related_2  \
# 0                a certified   network certified                     laptops
# 1  a certified it technician         n certified           network certified
# 2   a certified professional   network certified   comptia network certified
# 3            a quick learner  product validation  great communication skills
# 4                a1 assessor               ptlls           assessor training
#
#                    related_3                         related_4  \
# 0                n certified                 computer hardware
# 1  comptia network certified           comptia a certification
# 2                n certified  microsoft certified professional
# 3                      vista          good communication skill
# 4                       nvqs                 training delivery
#
#                    related_5           related_6            related_7  \
# ...

# %%
skills_df.shape
# Out:
# (28934, 11)

# %%
skills_df.value_counts()
# Out:
# name                   related_1               related_2                                   related_3                                 related_4             related_5            related_6              related_7               related_8                   related_9                          related_10
# a certified            network certified       laptops                                     n certified                               computer hardware     windows 7            comptia                troubleshooting         software installation       printers                           xp                 1
# personal grooming      male grooming           bathing                                     personality development                   feeding               corporate etiquette  medication reminders   dining etiquette        corporate image management  etiquette                          email etiquette    1
# ...

# %%
skills_df.describe()
# Out:
#                name related_1 related_2   related_3   related_4   related_5  \
# count         28934     28934     28932       28923       28915       28906
# unique        28934     15114     14576       14546       14583       14605
# top     a certified         c         c  javascript  javascript  javascript
# freq              1       167        84          68          65          54
#
#          related_6 related_7   related_8   related_9  related_10
# count        28903     28894       28889       28887       28886
# unique       14576     14838       14699       14775       15021
# top     javascript         c  javascript  javascript  javascript
# freq            48        40          37          42          37
